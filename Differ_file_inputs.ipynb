# %% [markdown]
# DIFFERENT FILE FORMATS

# %%
# !pip install --upgrade pip
# !pip install sentence-transformers langchain chromadb pypdf faiss-cpu  langchain_community scikit-learn matplotlib seaborn numpy mistralai langchain-mistralai langchain_classic
# !pip install unstructured python-pptx
# !pip install unstructured openpyxl pandas
# !pip install unstructured python-docx
# !pip install msoffcrypto-tool
# !pip install unstructured

# %%
import os
os.environ["MISTRAL_API_KEY"]="mqOthjgXR0Bme2QCz8cFN8eITRl84xDJ"
from getpass import getpass

if not os.getenv("MISTRAL_API_KEY"):
    os.environ["MISTRAL_API_KEY"] = getpass("Enter your Mistral API Key: ")

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS,Chroma
from langchain_classic.schema import Document
import os

# %% [markdown]
# PDF Uploder

# %%
from langchain_community.document_loaders import PyPDFLoader

loader1 = PyPDFLoader("/content/Artificial Intelligence.pdf")
docs1 = loader1.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs1)
print(f"Loaded {len(docs1)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 3 docs, split into 7 chunks
# 1  What is Artificial Intelligence?
# Artificial Intelligence (AI) is the simulation of human intelligence in machines.
# It enables computers to perform tasks that typically require human reasoning, learning, problem-
# solving, and decision-making.
# The goal of AI is not just automation, but to create systems that can adapt and improve over time.
#
#  2 - Key Components of AI
# AI is built using multi

# %% [markdown]
# CSV EXCEL Uploder

# %%
from langchain_community.document_loaders import CSVLoader

loader2 = CSVLoader(file_path="/content/MAIN_PROJECT.csv")
docs2 = loader2.load()


splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs2)
print(f"Loaded {len(docs2)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 4000 docs, split into 4000 chunks
# Date: 01-01-2024
# Time: 00:00
# CO(GT): 3.807947177
# NOx(GT): 172.0267676
# NO2(GT): 144.3333169
# O3(GT): 118.1208316
# SO2(GT): 1.215678841
# PM2.5: 147.3496706
# PM10: 208.8031244
# Temperature: 28.56457954
# Humidity: 12.39919524
# Pressure: 1041.659237
# WindSpeed: 5.978240824
# WindDirection: 209.9842668
# CO_NOx_Ratio: 0.02200785
# NOx_NO2_Ratio: 1.183670553
# Temp_Humidity_Index: 3.541777988
# AirQualityIndex: 343.353046

# %% [markdown]
# TXT Uploader

# %%
from langchain_community.document_loaders import TextLoader
loader3 = TextLoader("/content/requirements.txt", encoding="utf-8")
docs3 = loader3.load()


splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs3)
print(f"Loaded {len(docs3)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 1 docs, split into 1 chunks
# langchain
# pypdf
# tiktoken
# faiss-cpu
# langchain-community
# pytesseract
# pdf2image
# langchain-text-splitters

# %% [markdown]
# PPT Uploder

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader
loader4 = UnstructuredPowerPointLoader("/content/Air-Quality-Index-Prediction-A-Data-Driven-Approach.pptx")
docs4 = loader4.load()


splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs4)
print(f"Loaded {len(docs4)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 1 docs, split into 18 chunks
# Air Quality Index Prediction: A Data-Driven Approach
#
# PRESENTED BY TEAM-C21
#
# 219X1A0512 – B. Sandhya
#
# 219X1A0506 – A. Ravalika
#
# 219X1A05E1 – K. Abhinav Kashyap
#
# PROJECT GUIDE:
#
# SRI.Y.R. Janardhan Reddy
#
# Assistant Professor
#
# Department of CSE
#
#
#
# Abstract
#
# Air Quality Index (AQI)
#
# Data-Driven Prediction
#
# A measure of air quality based on the concentration of various pollutants.
#
# Utilizing machine l

# %% [markdown]
# EXCEL Uploder

# %%
from langchain_community.document_loaders import UnstructuredExcelLoader

loader5 = UnstructuredExcelLoader("/content/Provisional Seniority List.xlsx")
docs5 = loader5.load()



splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs5)
print(f"Loaded {len(docs5)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 1 docs, split into 4225 chunks
# # Zone Code Zone Name District Code District Name Division Code Division Name Mandal Code Mandal Name Mc Code Mc Name School Code School Name Treasury Id Transfer Id Teacher Name Date Of Birth DOJ Present Category Date Of First Apt. Station Join Date Post Name Subject Code Subject Name Medium Code Medium Name Gender Marital Status Scl Present Management First Apt Management Willing Migrate Managem

# %% [markdown]
# DOCX Uploder

# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader


loader = UnstructuredWordDocumentLoader("/content/AIR QUALITY INDEX PREDICTION.docx")
docs = loader.load()



splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(docs)
print(f"Loaded {len(docs)} docs, split into {len(chunks)} chunks")
# inspect one
print(chunks[0].page_content[:400])
# Out:
# Loaded 1 docs, split into 19 chunks
# AIR QUALITY INDEX PREDICTION
#
# A Project report submitted	in partial fulfillment of requirements for the award of a degree of
#
# BACHELOR OF TECHNOLOGY
#
# IN
#
# COMPUTER SCIENCE AND ENGINEERING
#
# by
#
# BUDILI SANDHYA (219X1A0512)
#
# Under the esteemed guidance of
#
# Sri. Y. R Janardhan Reddy
#
# Assistant Professor
#
#  Department of C.S.E.
#
# Department of Computer Science and Engineering
#
# G. PULLA REDDY ENGINEERI
